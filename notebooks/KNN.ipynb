# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %%
df = pd.read_csv("data\Gaming_and_Mental_Health.csv")

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   record_id                         1000 non-null   str
#  1   age                               1000 non-null   int64
#  2   gender                            1000 non-null   str
#  3   daily_gaming_hours                1000 non-null   float64
#  4   game_genre                        1000 non-null   str
#  5   primary_game                      1000 non-null   str
#  6   gaming_platform                   1000 non-null   str
#  7   sleep_hours                       1000 non-null   float64
#  8   sleep_quality                     1000 non-null   str
#  9   sleep_disruption_frequency        1000 non-null   str
#  10  academic_work_performance         1000 non-null   str
#  11  grades_gpa                        754 non-null    float64
# ...

# %%
df.head(10)
# Out:
#   record_id  age  gender  daily_gaming_hours     game_genre  \
# 0    GD0001   17    Male                11.1   Mobile Games
# 1    GD0002   21    Male                 3.0           MOBA
# 2    GD0003   23    Male                 7.6            FPS
# 3    GD0004   20  Female                 7.2            RPG
# 4    GD0005   18    Male                 6.8  Battle Royale
# 5    GD0006   21    Male                 2.1   Mobile Games
# 6    GD0007   21    Male                 2.7            FPS
# 7    GD0008   28  Female                10.3   Mobile Games
# 8    GD0009   18    Male                 1.4   Mobile Games
# 9    GD0010   18    Male                 7.6            MMO
#
#         primary_game gaming_platform  sleep_hours sleep_quality  \
# 0     Clash of Clans              PC          3.7     Very Poor
# 1             Dota 2              PC          7.2          Fair
# 2              CS:GO  Multi-platform          4.4          Fair
# ...

# %%
df["grades_gpa"].describe()
df["work_productivity_score"].describe()
# Out:
# count    674.000000
# mean       5.394659
# std        2.898742
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        8.000000
# max       10.000000
# Name: work_productivity_score, dtype: float64

# %%
import plotly.express as px

px.histogram(df, x="grades_gpa")
px.histogram(df, x="work_productivity_score")

# %%
px.box(df, x="gaming_addiction_risk_level", y="grades_gpa")
px.box(df, x="gaming_addiction_risk_level", y="work_productivity_score")

# %%
df["gaming_addiction_risk_level"].value_counts()
# Out:
# gaming_addiction_risk_level
# Low         514
# Moderate    190
# High        154
# Severe      142
# Name: count, dtype: int64

# %%
px.box(df, x="gaming_addiction_risk_level", y="grades_gpa")

# %%
df.drop(columns=["grades_gpa", "work_productivity_score"], inplace=True)

# %%
px.box(df, x="gaming_addiction_risk_level", y="age")

# %%
px.box(df, x="gaming_addiction_risk_level", y="age")

# %%
px.box(df, x="gaming_addiction_risk_level", y="daily_gaming_hours")

# %%
px.histogram(df, x="game_genre", color="gaming_addiction_risk_level")

# %%
px.histogram(df, x="primary_game", color="gaming_addiction_risk_level")

# %%
px.histogram(df, x="gaming_platform", color="gaming_addiction_risk_level")

# %%
px.box(df, x="gaming_addiction_risk_level", y="sleep_hours")

# %%
px.histogram(df, x="sleep_quality", color="gaming_addiction_risk_level")

# %%
px.histogram(df, x="sleep_disruption_frequency", color="gaming_addiction_risk_level")

# %%
px.histogram(df, x="academic_work_performance", color="gaming_addiction_risk_level")

# %%
px.histogram(df, x="mood_state", color="gaming_addiction_risk_level")

# %%
px.histogram(df, x="mood_swing_frequency", color="gaming_addiction_risk_level")

# %%
px.histogram(df, x="withdrawal_symptoms", color="gaming_addiction_risk_level")

# %%
px.histogram(df, x="loss_of_other_interests", color="gaming_addiction_risk_level")

# %%
px.histogram(df, x="continued_despite_problems", color="gaming_addiction_risk_level")

# %%
px.histogram(df, x="eye_strain", color="gaming_addiction_risk_level")

# %%
px.histogram(df, x="back_neck_pain", color="gaming_addiction_risk_level")

# %%
px.box(df, x="gaming_addiction_risk_level", y="weight_change_kg")

# %%
px.box(df, x="gaming_addiction_risk_level", y="exercise_hours_weekly")

# %%
px.box(df, x="gaming_addiction_risk_level", y="social_isolation_score")

# %%
px.box(df, x="gaming_addiction_risk_level", y="face_to_face_social_hours_weekly")

# %%
px.box(df, x="gaming_addiction_risk_level", y="monthly_game_spending_usd")

# %%
px.box(df, x="gaming_addiction_risk_level", y="years_gaming")

# %%
df.head(10)
# Out:
#   record_id  age  gender  daily_gaming_hours     game_genre  \
# 0    GD0001   17    Male                11.1   Mobile Games
# 1    GD0002   21    Male                 3.0           MOBA
# 2    GD0003   23    Male                 7.6            FPS
# 3    GD0004   20  Female                 7.2            RPG
# 4    GD0005   18    Male                 6.8  Battle Royale
# 5    GD0006   21    Male                 2.1   Mobile Games
# 6    GD0007   21    Male                 2.7            FPS
# 7    GD0008   28  Female                10.3   Mobile Games
# 8    GD0009   18    Male                 1.4   Mobile Games
# 9    GD0010   18    Male                 7.6            MMO
#
#         primary_game gaming_platform  sleep_hours sleep_quality  \
# 0     Clash of Clans              PC          3.7     Very Poor
# 1             Dota 2              PC          7.2          Fair
# 2              CS:GO  Multi-platform          4.4          Fair
# ...

# %%
print(df["gaming_addiction_risk_level"].isnull().sum())
# Out:
# 0

# %%
bool_cols = [
    "withdrawal_symptoms",
    "loss_of_other_interests",
    "continued_despite_problems",
    "eye_strain",
    "back_neck_pain"
]

for col in bool_cols:
    if col in df.columns:
        if df[col].dtype == "object":
            df[col] = df[col].str.upper().map({
                "TRUE": 1,
                "FALSE": 0
            })
        else:
            df[col] = df[col].astype(int)

# %%
print(df["gaming_addiction_risk_level"].isnull().sum())
# Out:
# 0

# %%
categorical_cols = df.select_dtypes(include=["object"]).columns.tolist()
print("Categóricas:", categorical_cols)
# Out:
# Categóricas: ['record_id', 'gender', 'game_genre', 'primary_game', 'gaming_platform', 'sleep_quality', 'sleep_disruption_frequency', 'academic_work_performance', 'mood_state', 'mood_swing_frequency', 'gaming_addiction_risk_level']
# C:\Users\mathe\AppData\Local\Temp\ipykernel_21512\2595359756.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include=["object"]).columns.tolist()

# %%
print(df["gaming_addiction_risk_level"].isnull().sum())

# %%
categorical_cols = [
    "academic_work_performance",
    "mood_state",
    "sleep_quality",
    "sleep_disruption_frequency",
    "gaming_addiction_risk_level"
]

for col in categorical_cols:
    print(f"\n================ {col} ================")
    
    # valores únicos
    print("\nValores únicos:")
    print(df[col].unique())
    
    # contagem
    print("\nContagem:")
    print(df[col].value_counts())
    
    # proporção
    print("\nProporção:")
    print(df[col].value_counts(normalize=True))
# Out:
# ================ academic_work_performance ================
#
# Valores únicos:
# <ArrowStringArray>
# ['Below Average', 'Good', 'Poor', 'Average', 'Excellent', 'Failing']
# Length: 6, dtype: str
#
# Contagem:
# academic_work_performance
# Average          246
# Below Average    231
# Poor             183
# Good             174
# Excellent        103
# Failing           63
# Name: count, dtype: int64
#
# Proporção:
# academic_work_performance
# Average          0.246
# Below Average    0.231
# Poor             0.183
# Good             0.174
# Excellent        0.103
# Failing          0.063
# Name: proportion, dtype: float64
#
# ================ mood_state ================
#
# Valores únicos:
# <ArrowStringArray>
# [  'Anxious', 'Irritable', 'Withdrawn',     'Angry',    'Normal',  'Euphoric',
#   'Restless', 'Depressed',   'Excited']
# Length: 9, dtype: str
#
# Contagem:
# mood_state
# Normal       172
# Anxious      169
# Irritable    147
# Restless     135
# Euphoric     107
# ...

# %%
df.head(10)
# Out:
#   record_id  age  gender  daily_gaming_hours     game_genre  \
# 0    GD0001   17    Male                11.1   Mobile Games
# 1    GD0002   21    Male                 3.0           MOBA
# 2    GD0003   23    Male                 7.6            FPS
# 3    GD0004   20  Female                 7.2            RPG
# 4    GD0005   18    Male                 6.8  Battle Royale
# 5    GD0006   21    Male                 2.1   Mobile Games
# 6    GD0007   21    Male                 2.7            FPS
# 7    GD0008   28  Female                10.3   Mobile Games
# 8    GD0009   18    Male                 1.4   Mobile Games
# 9    GD0010   18    Male                 7.6            MMO
#
#         primary_game gaming_platform  sleep_hours sleep_quality  \
# 0     Clash of Clans              PC          3.7     Very Poor
# 1             Dota 2              PC          7.2          Fair
# 2              CS:GO  Multi-platform          4.4          Fair
# ...

# %%
print(df["gaming_addiction_risk_level"].isnull().sum())
# Out:
# 0

# %%
mapping_target = {
    "Low": 0,
    "Moderate": 1,
    "High": 2,
    "Severe": 3
}

df["gaming_addiction_risk_level"] = df["gaming_addiction_risk_level"].map(mapping_target)

# %%
print(df["gaming_addiction_risk_level"].isnull().sum())
# Out:
# 0

# %%
mapping_academic = {
    "Failing": 0,
    "Poor": 1,
    "Below Average": 2,
    "Average": 3,
    "Good": 4,
    "Excellent": 5
}

df["academic_work_performance"] = df["academic_work_performance"].map(mapping_academic)

# %%
mapping_target = {
    "Low": 0,
    "Moderate": 1,
    "High": 2,
    "Severe": 3
}

df["gaming_addiction_risk_level"] = df["gaming_addiction_risk_level"].map(mapping_target)

# %%
df["sleep_quality"] = df["sleep_quality"].replace({
    "Insomnia": "Very Poor"
})

mapping_sleep = {
    "Very Poor": 0,
    "Poor": 1,
    "Fair": 2,
    "Good": 3
}

df["sleep_quality"] = df["sleep_quality"].map(mapping_sleep)

# %%
df = pd.get_dummies(df, columns=["mood_state"], drop_first=True)

# %%
mood_cols = [col for col in df.columns if col.startswith("mood_state_")]

for col in mood_cols:
    df[col] = df[col].astype(int)

# %%
df[mood_cols].dtypes
# Out:
# mood_state_Anxious      int64
# mood_state_Depressed    int64
# mood_state_Euphoric     int64
# mood_state_Excited      int64
# mood_state_Irritable    int64
# mood_state_Normal       int64
# mood_state_Restless     int64
# mood_state_Withdrawn    int64
# dtype: object

# %%
print(df.dtypes)
# Out:
# record_id                               str
# age                                   int64
# gender                                  str
# daily_gaming_hours                  float64
# game_genre                              str
# primary_game                            str
# gaming_platform                         str
# sleep_hours                         float64
# sleep_quality                         int64
# sleep_disruption_frequency              str
# academic_work_performance             int64
# mood_swing_frequency                    str
# withdrawal_symptoms                   int64
# loss_of_other_interests               int64
# continued_despite_problems            int64
# eye_strain                            int64
# back_neck_pain                        int64
# weight_change_kg                    float64
# exercise_hours_weekly               float64
# social_isolation_score                int64
# face_to_face_social_hours_weekly    float64
# ...

# %%
# =========================
# SUBSET - ALTA CORRELAÇÃO
# =========================

features_alta = [
    "daily_gaming_hours",
    "withdrawal_symptoms",
    "loss_of_other_interests",
    "continued_despite_problems",
    "exercise_hours_weekly",
    "social_isolation_score",
    "face_to_face_social_hours_weekly",
    "monthly_game_spending_usd",
    "sleep_hours",
    "academic_work_performance"
]

target = "gaming_addiction_risk_level"

# criando dataset
df_alta = df[features_alta + [target]].copy()

# separando X e y
X_alta = df_alta[features_alta]
y_alta = df_alta[target]

print("Shape X_alta:", X_alta.shape)
print("Shape y_alta:", y_alta.shape)
# Out:
# Shape X_alta: (1000, 10)
# Shape y_alta: (1000,)

# %%
# =========================
# SUBSET - ALTA + MÉDIA
# =========================

# pegar automaticamente as colunas de mood_state
mood_cols = [col for col in df.columns if col.startswith("mood_state_")]

features_media = [
    "sleep_quality",
    "eye_strain",
    "back_neck_pain",
    "weight_change_kg"
] + mood_cols

features_alta_media = features_alta + features_media

# criando dataset
df_alta_media = df[features_alta_media + [target]].copy()

# separando X e y
X_alta_media = df_alta_media[features_alta_media]
y_alta_media = df_alta_media[target]

print("Shape X_alta_media:", X_alta_media.shape)
print("Shape y_alta_media:", y_alta_media.shape)
# Out:
# Shape X_alta_media: (1000, 22)
# Shape y_alta_media: (1000,)

# %%
print("ALTA:")
print(X_alta.dtypes)

print("\nALTA + MÉDIA:")
print(X_alta_media.dtypes)
# Out:
# ALTA:
# daily_gaming_hours                  float64
# withdrawal_symptoms                   int64
# loss_of_other_interests               int64
# continued_despite_problems            int64
# exercise_hours_weekly               float64
# social_isolation_score                int64
# face_to_face_social_hours_weekly    float64
# monthly_game_spending_usd           float64
# sleep_hours                         float64
# academic_work_performance             int64
# dtype: object
#
# ALTA + MÉDIA:
# daily_gaming_hours                  float64
# withdrawal_symptoms                   int64
# loss_of_other_interests               int64
# continued_despite_problems            int64
# exercise_hours_weekly               float64
# social_isolation_score                int64
# face_to_face_social_hours_weekly    float64
# monthly_game_spending_usd           float64
# sleep_hours                         float64
# academic_work_performance             int64
# ...

# %%
df_alta_media.head(10)
# Out:
#    daily_gaming_hours  withdrawal_symptoms  loss_of_other_interests  \
# 0                11.1                    1                        0
# 1                 3.0                    0                        0
# 2                 7.6                    1                        1
# 3                 7.2                    1                        1
# 4                 6.8                    1                        0
# 5                 2.1                    0                        0
# 6                 2.7                    0                        0
# 7                10.3                    1                        1
# 8                 1.4                    0                        0
# 9                 7.6                    1                        1
#
#    continued_despite_problems  exercise_hours_weekly  social_isolation_score  \
# 0                           1                    3.7                       7
# ...

# %%
print(df["gaming_addiction_risk_level"].isnull().sum())
# Out:
# 1000

# %%
print("NaN em y_alta:", y_alta.isnull().sum())
# Out:
# NaN em y_alta: 1000

# %%
from sklearn.preprocessing import StandardScaler

scaler_alta = StandardScaler()
X_alta_scaled = scaler_alta.fit_transform(X_alta)

scaler_alta_media = StandardScaler()
X_alta_media_scaled = scaler_alta_media.fit_transform(X_alta_media)

# %%
from sklearn.model_selection import train_test_split

X_train_a, X_test_a, y_train_a, y_test_a = train_test_split(
    X_alta_scaled, y_alta, test_size=0.2, random_state=42
)

# %%
from sklearn.model_selection import train_test_split

X_train_a, X_test_a, y_train_a, y_test_a = train_test_split(
    X_alta_scaled, y_alta, test_size=0.2, random_state=42
)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

k_values = range(1, 21)
scores_alta = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_a, y_train_a)
    
    y_pred = knn.predict(X_test_a)
    acc = accuracy_score(y_test_a, y_pred)
    
    scores_alta.append(acc)

for k, score in zip(k_values, scores_alta):
    print(f"K={k} → Accuracy={score:.4f}")

scores_alta_media = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_am, y_train_am)
    
    y_pred = knn.predict(X_test_am)
    acc = accuracy_score(y_test_am, y_pred)
    
    scores_alta_media.append(acc)

for k, score in zip(k_values, scores_alta_media):
    print(f"K={k} → Accuracy={score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1247], line 9
#       7 for k in k_values:
#       8     knn = KNeighborsClassifier(n_neighbors=k)
# ----> 9     knn.fit(X_train_a, y_train_a)
#      11     y_pred = knn.predict(X_test_a)
#      12     acc = accuracy_score(y_test_a, y_pred)
#
# File c:\MLops\venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\MLops\venv\Lib\site-packages\sklearn\neighbors\_classification.py:243, in KNeighborsClassifier.fit(self, X, y)
#     221 @_fit_context(
# ...

# %%
scores_alta_media = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_am, y_train_am)
    
    y_pred = knn.predict(X_test_am)
    acc = accuracy_score(y_test_am, y_pred)
    
    scores_alta_media.append(acc)

for k, score in zip(k_values, scores_alta_media):
    print(f"K={k} → Accuracy={score:.4f}")
